# %% [markdown]
# ## Text Preprocessing Level 1 - Tokenization,Lemmatization,Stopwords,POS

# %% [markdown]
# ### T1 - Tokenization
#
# Converting Paragraph into sentences and words . We will use APJ abdul kalam speech and will do various text preprocessing on that speech
#
# See Practical.py file
#
# ### T2 - Stemming and Lemmatization
#
# Process of Reducing infected words to their word stem.  \
# In stemming all words will get converted to their root word using the most occurence alphabets.  \
# In Lemmatization , It converts to their root word which has some meaning it, i-e It converts into meaningful word.
#
# Lemmatization takes more time then Stemming
#
# Stemming Application - Spam classifier,Positive Negative Classifier
# Lemmatization - Chatbot,Q&A (Meaningful response should be given so that human can understand
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### T3 - Stemming Practical
#
# See Practical Notebook

# %% [markdown]
# ### T4 - Lemmatization Practical
#
# See Practical Notebook
